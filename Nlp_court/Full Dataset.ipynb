# %% [markdown]
# # Full Dataset

# %%
import json

# %%
full_data = json.load(open('amy_cases.json', 'r'))

# %%
type(full_data)
# Out:
# dict

# %%
file_name = list(full_data.keys())

# %%
file_text = []
for key in file_name:
    file_text.append(full_data[key])

# %%
len(file_text)
# Out:
# 854

# %%
print(file_text[0])
# Out:
# Apple Inc. v. International Trade Com'n, 725 F.3d 1356 (2013)
# 35 ITRD 1921, 107 U.S.P.Q.2d 1864
#
# KeyCite Yellow Flag - Negative Treatment
#
# Distinguished by CAPTIONCALL, LLC, PETITIONER, v. ULTRATEC, INC., PATENT OWNER., Patent Tr. &amp; App. Bd., December 1, 2015
#
#
# 725 F.3d 1356
#
# United States Court of Appeals,
#
# Federal Circuit.
#
# APPLE INC., Appellant,
#
# v.
#
# INTERNATIONAL TRADE COMMISSION, Appellee,
#
# and
#
# Motorola Mobility, Inc., Intervenor.
#
# No. 2012–1338.
#
# |
#
# Aug. 7, 2013.
#
# |
#
# Rehearing and Rehearing En Banc Denied Nov. 8, 2013.
#
# Synopsis
# Background: Patentee initiated proceedings alleging that competitor's smartphones and tablets infringed claims of patents
# pertaining to smartphone touchscreens. Competitor intervened. The United States International Trade Commission
# (ITC) ruled that claims of patent disclosing touch panel with transparent capacitive sensing medium capable of detecting
# ...
